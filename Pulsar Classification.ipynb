# %% [markdown]
# #### Extract data from zip file

# %%
import pandas

DATA_PATH = "C:\Users\hugoj\JupyterProjects\datasets\pulsars\HTRU2\HTRU_2.csv"

def load_pulsar_data():
    return pandas.read_csv(DATA_PATH)

data = load_pulsar_data()
pulsar_features = data[:-1]

# %% [markdown]
# #### Examine the first few rows of data

# %%
pulsar_features.head()
# Out:
#       IP-Mean    IP-SDEV  IP-EX_KURTOSIS   IP-SKEW  DMSNR-MEAN  DMSNR-SDEV  \
# 0  140.562500  55.683782       -0.234571 -0.699648    3.199833   19.110426
# 1  102.507812  58.882430        0.465318 -0.515088    1.677258   14.860146
# 2  103.015625  39.341649        0.323328  1.051164    3.121237   21.744669
# 3  136.750000  57.178449       -0.068415 -0.636238    3.642977   20.959280
# 4   88.726562  40.672225        0.600866  1.123492    1.178930   11.468720
#
#    DMSNR-EX_KURTOSIS  DMSNR-SKEW  LABEL
# 0           7.975532   74.242225      0
# 1          10.576487  127.393580      0
# 2           7.735822   63.171909      0
# 3           6.896499   53.593661      0
# 4          14.269573  252.567306      0

# %% [markdown]
# #### Graph all data columns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

pulsar_clean_data.hist(bins=50, figsize=(11, 8))
plt.show()

# %% [markdown]
# #### Normalize data

# %%
from sklearn.preprocessing import MaxAbsScaler

normalizer = MaxAbsScaler()
normalizer.fit(pulsar_clean_data)
normalized_data = normalizer.transform(pulsar_clean_data)

pulsar_normalized_data = pandas.DataFrame(data=normalized_data, columns=list(pulsar_clean_data))
pulsar_normalized_data.head()
pulsar_normalized_data.hist(bins=50, figsize=(11, 8))
#plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000093C0E80>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C2BE278>]], dtype=object)
